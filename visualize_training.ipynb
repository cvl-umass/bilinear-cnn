# %%
# matploblib inline

# %%
import matplotlib.pyplot as pyplt
from plot_curve import plot_log
import matplotlib
import os

# %%
log_path = os.path.join('../exp/bcnn_vd_cub/train_init_history.txt')
out_path = os.path.join('../exp/bcnn_vd_cub/training_init_curve.png')
val_acc = plot_log(log_path, out_path, False)
print('best val accuracy: %.3f'%val_acc)
# Out:
# best val accuracy: 0.775
